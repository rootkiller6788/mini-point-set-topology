# %% [markdown]
# # Separation Axioms Explorer\n\nInteractive exploration of T0-T6 separation axioms.\nThis notebook provides visualizations and computational checks\nfor finite topological spaces.

# %%
# Placeholder for separation axiom computation notebook\nprint('Separation Axioms Explorer — stub')
